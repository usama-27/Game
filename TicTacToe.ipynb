# %%
def gam(g):
    g = [['','',''],['','',''],['','','']]

# %%
def game_dis(g):
    print ('\n',g[0],'\n',g[1],'\n',g[2])

# %%
def player01():
    game_dis(game)
    
    print('\n--------------------------------------------------\n\n')
    
    user_in1 = input("Player01 Enter the move you want to take (format is row,column): ")
    
    move = user_in1.split(",")
    
    for i in range(len(move)):
        move[i] = int(move[i])
        move[i] -= 1
        
    
    j=move[0] 
    k=move[1]
    
    game[j][k] = 'X'
    
    game_dis(game)

# %%
def player02():
    user_in2 = input("Player02 Enter the move you want to take (format is row,column): ")
            
    move = user_in2.split(",")
    
    for i in range(len(move)):
        move[i] = int(move[i])
        move[i] -= 1
        
    
    j=move[0] 
    k=move[1]
    
    game[j][k] = 'O'
    
    game_dis(game)
    
    
    
    time.sleep(2)
    
    clear_output()

# %%
def game_win(gw):

    #game_dis(gw)
    
    if ((gw[0][0]=='X' and gw[0][1]=='X' and gw[0][2]=='X')or
    (gw[0][0]=='X' and gw[1][1]=='X' and gw[2][2]=='X')or
    (gw[0][0]=='X' and gw[1][0]=='X' and gw[2][0]=='X')or
    (gw[0][1]=='X' and gw[1][1]=='X' and gw[2][1]=='X')or
    (gw[0][2]=='X' and gw[1][2]=='X' and gw[2][2]=='X')or
    (gw[1][0]=='X' and gw[1][1]=='X' and gw[1][2]=='X')or
    (gw[2][0]=='X' and gw[2][1]=='X' and gw[2][2]=='X')or
    (gw[0][2]=='X' and gw[1][1]=='X' and gw[2][0]=='X')):
        
        
        
        print('\n Player 1 is won ')
 
        
        return True
    
      
        
    elif ((gw[0][0]=='O' and gw[0][1]=='O' and gw[0][2]=='O')or
    (gw[0][0]=='O' and gw[1][1]=='O' and gw[2][2]=='O')or
    (gw[0][0]=='O' and gw[1][0]=='O' and gw[2][0]=='O')or
    (gw[0][1]=='O' and gw[1][1]=='O' and gw[2][1]=='O')or
    (gw[0][2]=='O' and gw[1][2]=='O' and gw[2][2]=='O')or
    (gw[1][0]=='O' and gw[1][1]=='O' and gw[1][2]=='O')or
    (gw[2][0]=='O' and gw[2][1]=='O' and gw[2][2]=='O')or
    (gw[0][2]=='O' and gw[1][1]=='O' and gw[2][0]=='O')):
        
        
        print('\n Player 2 is won ')
        return True
        
#     else:
#         print('\n Match Tie')

# %%
def game_on():
    
    from IPython.display import clear_output
    import time
    
    game = [['','',''],['','',''],['','','']]
    
    choice1 = False
    choice2 = False
    
    lista=[0,1,2,3]
    seta = ['1','2','3',',']
    
    u=0
    p=0
    c=False
    ab=1
    ad=1
    
    
    
    
        
    while game_win(game) != True:
        
        game_dis(game)
        
        print('\n--------------------------------------------------\n\n')
        
        entry1=False
        entry2=False
        
        while entry1!= True:
            try:
                user_in1 = input("Player01 Enter the move you want to take (format is row,column): ")
            
                move = user_in1.split(",")
            
                moveset = set(move)
            
                if moveset.issubset(seta):
        #            ab=0
        #        else:
        #            ab=1
            
                
            
            
                        for i in range(len(move)):
                        
                            move[i] = int(move[i])
                            move[i] -= 1
                    
                            if all(item in lista for item in move):
                        
                                j=move[0] 
                                k=move[1]
                        
                                game[j][k] = 'X'
                        
                                game_dis(game)
                            
                            
                                entry1=True
                            
                    
                            else:
                                print('')
                else:
                    clear_output()
                    print("\nEnter the correct value range! \nTry Again")
            except:
                
                print('Error! enter the correct value')
#                 else:
                    
#                     
#                     print("\nEnter the correct value range! \nTry Again")
                
        if game_win(game) == True:
            break 
        else:
        
        
            while entry2!=True:
                try:
                    
            
                    user_in2 = input("Player02 Enter the move you want to take (format is row,column): ")
                    
                    move = user_in2.split(",")
                    
                    moveset = set(move)
                    
                    if moveset.issubset(seta):
                        
            #             ad=0
            #         else:
            #             ad=1
                        
                        
            #         choice2 = True
                    
                        for i in range(len(move)):
                            move[i] = int(move[i])
                            move[i] -= 1
                        
                        
                            if all(item in lista for item in move):
                            
                                j=move[0] 
                                k=move[1]
                            
                                game[j][k] = 'O'
                            
                                game_dis(game)
                            
                                time.sleep(2)
                            
                                clear_output()
                            
                                
                                
                                entry2 = True
                            else:
                                print('')
                            
                                
                    else:
                        choice2 = False
                        print("\nEnter the correct value ! \nTry again")
                except:
                    print('\nError enter the correct value!\n')
       
        game_win(game)
    
    
    
    
    clear_output()
    
    
    game_dis(game)
    game_win(game)
    
    while c != True:
        
        choice = input("If you want to play again Y,N: ").upper()
        clear_output()
        if choice == 'Y':
            game_on()
        elif choice == 'N':
            print("\nThanks for playing Game!\n")
            c = True
        else:
            print("\nEnter correct value!")

# %%
game_on()
# Out:
#  ['X', '', '']
#  ['', 'O', '']
#  ['', '', '']
#
# --------------------------------------------------
